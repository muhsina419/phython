# %% [markdown]
# 1.find the largest among two numbers

# %%
#integer
n1=int(input("Enter a number : "))
n2=int(input("Enter another number : "))
if (n1>n2):
  print(n1," is the largest number")
else:
  print(n2," is the largest number")
# Out:
# Enter a number : 56
# Enter another number : 65
# 65  is the largest number

# %% [markdown]
# 2.check whether the number is even or odd

# %%
#integer
n=int(input("Enter a number : "))
if(n%2==0):
  print(n," is a even number")
else:
  print(n," is a odd number")
# Out:
# Enter a number : 467
# 467  is a odd number

# %% [markdown]
# 3.check whether a number is positive , negetive or zero

# %%
#integer
n=int(input("enter a number : "))
if(n>0):
  print(n,"is a positive number")
elif(n==0):
  print("the number is zero")
else:
  print(n," is a negetive number")
# Out:
# enter a number : -9
# -9  is a negetive number

# %% [markdown]
# 4.Check whether a number is two digit or not

# %%
#integer
n=int(input("Enter a number"))
if(n>9 and n<100):
  print(n," is a two digit number")
else:
  print(n," is not a two digit number")
# Out:
# Enter a number3
# 3  is not a two digit number

# %% [markdown]
# 5.Check the nature of solution of quadratic equation

# %%
#integer
a=int(input("Enter the co-efficient of x^2 : "))
b=int(input("Enter the co-efficient of x : "))
c=int(input("Enter the constant : "))
d=(b*b)-(4*a*c)
if(d>0):
  print("The roots are real and distinct")
elif(d==0):
  print("The roots are real and equal")
else:
  print("The roots are imaginary")
# Out:
# Enter the co-efficient of x^2 : 1
# Enter the co-efficient of x : 8
# Enter the constant : 1
# The roots are real and distinct

# %% [markdown]
# 6.Find the smallest among two numbers

# %%
#integer
a=int(input("Enter the first  number "))
b=int(input("Enter the second number"))
c=int(input("Enter the third number"))
if (a<b and a<c):
  print(a," is the smallest")
elif(b<c):
  print(b," is the smallest")
else:
  print(c," is the smallest")
# Out:
# Enter the first  number 1
# Enter the second number3
# Enter the third number3
# 1  is the smallest

# %% [markdown]
# 7.Find the smallest number in a two digit number

# %%
#integer
n=int(input("enter a two digit number"))
d2=int(n%10)
d1=int(n/10)
if(d1<d2):
  print(d1," is the smallest")
else:
  print(d2," is the smallest")
# Out:
# enter a two digit number86
# 6  is the smallest

# %% [markdown]
# 8.Check whether a number is divisible by other

# %%
#integer
n1=int(input("Enter a number : "))
n2=int(input("Enter another number : "))
if(n1%n2==0):
  print(n1," is divisible by ",n2)
else:
  print(n1," is not divisible by ",n2 )
# Out:
# Enter a number9
# Enter another number3
# 9  is divisible by  3

# %% [markdown]
# 9.Find the distance between the points on a number line

# %%
#integer
n1=int(input("Enter the first point on the number line : "))
n2=int(input("Enter the second point on the number line : "))
d=int(abs(n1-n2))
print(d," is the distance between two points")
# Out:
# Enter the first point on the number line : 6
# Enter the second point on the number line : 9
# 3  is the distance between two points

# %% [markdown]
# 10.Check whether a year is leap or not

# %%
#integer
y=int(input("Enter a year : "))
r1=y%4
if(r1==0):
  r2=y%100
  if(r2==0):
    r3=y%400
    if(r3==0):
      print(y," is a leap year")
    else:
      print(y," is not a leap year")
  else:
    print(y," is leap year")
else:
  print(y," is not a leap year")
# Out:
# Enter a year : 00100
# 100  is not a leap year
