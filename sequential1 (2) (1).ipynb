# %% [markdown]
# # Write a program to find the sum of two numbers

# %%
#integer
#float
n1=float(input("enter the first number : "))
n2=float(input("enter the second number : "))
sum=n1+n2
print("sum is",sum)
# Out:
# enter the first number : 3
# enter the second number : 5
# sum is 8.0

# %% [markdown]
# # Calculate the area of the circle

# %%
#integer
r=int(input("enter the radius of the circle :"))
pi=3.14
area=pi*r*r
print("the area of th circle is :",area)
# Out:
# enter the radius of the circle :6
# the area of th circle is : 113.03999999999999

# %% [markdown]
# # Calculate the sum and average of three numbers

# %%
#integer
n1=int(input("enter the first number : "))
n2=int(input("enter the second number : "))
n3=int(input("enter the third number : "))
sum=n1+n2+n3
avg=sum/3
print("sum is : ",sum)
print("average is : ",avg)
# Out:
# enter the first number : 9
# enter the second number : 8
# enter the third number : 4
# sum is :  21
# average is :  7.0

# %% [markdown]
# # Calculate the area and perimeter of triangle

# %%
#integer
a=int(input("enter the first side of the triangle : "))
b=int(input("enter the second side of the triangle : "))
c=int(input("enter the third side of the triangle : "))
p=a+b+c
s=p/2
area=(s*(s-a)*(s-b)*(s-c))**(1/2)
print("perimeter of the triangle : ",p)
print("area of the triangle is : ",area)
# Out:
# enter the first side of the triangle : 3
# enter the second side of the triangle : 4
# enter the third side of the triangle : 5
# perimeter of the triangle :  12
# area of the triangle is :  6.0

# %% [markdown]
# # Calculate the no.of years,months and weeks from a given no.of days

# %%
#integer

n=int(input("enter the no of days "))
y=int(n/365)
a=n%365
m=int(a/30)
d=a%30
print(y,"  years, ",m,"  months and ",d," days")

# %% [markdown]
# # Convert seconds to hour,minute and seconds

# %%
#integer
n=int(input("enter the seconds"))
h=int(n/3600)
a=n%3600
m=int(a/60)
d=a%60
print(h,"  hours",m,"  minutes and ",d," seconds")
# Out:
# enter the seconds3680
# 1   hours 1   minutes and  20  seconds

# %% [markdown]
# # Calculate sum,difference,product and quotient of two numbers

# %%
#integer
a=int(input("enter the first number"))
b=int(input("enter the second number"))
sum=a+b
diff=a-b
prod=a*b
quo=a/b
print("sum is",sum)
print("difference is",diff)
print("product is",prod)
print("quotient is",quo)
# Out:
# enter the first number3
# enter the second number4
# sum is 7
# difference is -1
# product is 12
# quotient is 0.75

# %% [markdown]
# # Find the roots of the quadratic equation

# %%
#integer
import math

a=int(input(" enter the co-efficient of x^2 "))
b=int(input("enter the co-efficient of x "))
c=int(input("enter the constant "))
d=math.sqrt(b*b)-(4*a*c)
r1=(-b+d)/(2*a)
r2=(-b-d)/(2*a)
print("First root of the equation is ",r1)
print("Second root of the equation is ",r2)
# Out:
#  enter the co-efficient of x^2 2
# enter the co-efficient of x 4
# enter the constant 6
# First root of the equation is  -12.0
# Second root of the equation is  10.0

# %% [markdown]
# # Calculate the percentage of 5 subjects

# %%
#integer
m1=int(input("enter the mark of maths out of 100"))
m2=int(input("enter the marks of phython out of 100"))
m3=int(input("enter the marks of c++ out of 100"))
m4=int(input("enter the marks of CT out of 100"))
m5=int(input("enter the marks of english out of 100"))
sum=m1+m2+m3+m4+m5
perc=(sum/500)*100
print("percentage of 5 subjects is ",p)

# %% [markdown]
# # Convert celcuis to farenheit

# %%
#integer
c=int(input("enter the temparature in celcuis :"))
f=c*9/5+32
print("temparature in farenheit is : ",f)
# Out:
# enter the temparature in celcuis :320
# temparature in farenheit is :  608.0
